# %% [markdown]
# # 🏀 US College Basketball Data Visualization – Final Report
#
# This project explores the **US College Basketball dataset** using **Seaborn** and **Matplotlib**.
# We created multiple visualizations such as **bar plots, box plots, KDE plots, violin plots, and swarm plots** to analyze team performance and efficiency.
#
# The goal is to **find patterns, trends, and insights** in offensive and defensive efficiency, win distributions, and conference-wise performance.

# %% [markdown]
# ![pexels-tima-miroshnichenko-5586409.jpg](data:image/jpeg;base64,...)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
from google.colab import files
import pandas as pd

# Upload the file
uploaded = files.upload()

# Load the CSV into a DataFrame
df = pd.read_csv("US_college_basketball.csv")

# Display first 5 rows
df.head()
# Out:
#      <input type="file" id="files-feda581c-b931-4fec-b9a3-1cde28879892" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-feda581c-b931-4fec-b9a3-1cde28879892">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Basic info
print(df.shape)
# Out:
# (3885, 24)

# %% [markdown]
# ### Insights
# - The dataset contains **3885 rows and 24 columns**.
# - Each row represents a **college basketball team’s performance in a specific season**.
# - With 24 attributes (wins, efficiency, postseason, etc.), this dataset provides a **comprehensive view for analysis**.

# %%
df.head()
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2        Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3      Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4         Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  22.4  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015
# 2  ...  30.0  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018
# 3  ...  36.6  52.8  41.9  36.5  29.7   67.5   7.0         2ND   3.0  2019
# 4  ...  26.9  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Insights
# - The dataset includes **team-level details** like TEAM, CONF (conference), W (wins), and YEAR.
# - Statistical columns like **ADJOE (offensive efficiency)** and **ADJDE (defensive efficiency)** provide deeper performance metrics.
# - We can already see **diverse conferences** and performance variations among teams.

# %%
df.tail()
# Out:
#                         TEAM  CONF   G  W  ADJOE  ADJDE  BARTHAG  EFG_O  \
# 3880               Stonehill   NEC  30  4   90.3  114.2   0.0629   46.7
# 3881          St. Francis PA   NEC  28  8   93.1  118.1   0.0608   47.2
# 3882                   IUPUI  Horz  29  6   92.1  116.9   0.0607   46.5
# 3883              Coppin St.  MEAC  29  2   85.1  111.1   0.0445   42.1
# 3884  Mississippi Valley St.  SWAC  31  1   85.4  116.2   0.0283   42.5
#
#       EFG_D   TOR  ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  \
# 3880   52.7  19.5  ...  29.4  47.9  51.7  30.1  35.9   68.1 -22.0         NaN
# 3881   53.0  21.2  ...  35.4  45.7  52.9  33.2  35.4   65.4 -18.6         NaN
# 3882   58.2  21.3  ...  33.4  49.5  59.0  24.7  38.0   67.3 -21.6         NaN
# 3883   51.3  22.9  ...  38.3  41.9  51.0  28.3  34.5   66.3 -22.9         NaN
# 3884   55.6  24.0  ...  41.6  41.9  55.6  29.2  37.0   64.5 -22.7         NaN
#
#       SEED  YEAR
# 3880   NaN  2024
# 3881   NaN  2024
# ...

# %% [markdown]
# ### Insights
# - The last rows confirm that the dataset spans **multiple years**.
# - Smaller or less-known conferences are also included, giving a **comprehensive view** of college basketball performance.

# %%
print(df.columns)
# Out:
# Index(['TEAM', 'CONF', 'G', 'W', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG_O', 'EFG_D',
#        'TOR', 'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O',
#        '3P_D', 'ADJ_T', 'WAB', 'POSTSEASON', 'SEED', 'YEAR'],
#       dtype='object')

# %% [markdown]
# ### Insights
# - The dataset has **24 distinct columns**.
# - Key performance indicators include:
#   - **W (Wins)** → total wins per season
#   - **ADJOE / ADJDE** → adjusted offensive/defensive efficiency
#   - **BARTHAG** → power rating (win probability vs average team)
#   - **POSTSEASON** and **SEED** → tournament results and seedings
# - This richness enables both **team-level and conference-level analysis**.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3885 entries, 0 to 3884
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TEAM        3885 non-null   object
#  1   CONF        3885 non-null   object
#  2   G           3885 non-null   int64
#  3   W           3885 non-null   int64
#  4   ADJOE       3885 non-null   float64
#  5   ADJDE       3885 non-null   float64
#  6   BARTHAG     3885 non-null   float64
#  7   EFG_O       3885 non-null   float64
#  8   EFG_D       3885 non-null   float64
#  9   TOR         3885 non-null   float64
#  10  TORD        3885 non-null   float64
#  11  ORB         3885 non-null   float64
#  12  DRB         3885 non-null   float64
#  13  FTR         3885 non-null   float64
#  14  FTRD        3885 non-null   float64
#  15  2P_O        3885 non-null   float64
#  16  2P_D        3885 non-null   float64
#  17  3P_O        3885 non-null   float64
# ...

# %% [markdown]
# ### Insights
# - All columns are present with **no missing values** detected.
# - Columns are a mix of **object (categorical: TEAM, CONF, POSTSEASON)** and **numeric (W, ADJOE, ADJDE, etc.)**.
# - Data is already **clean and ready** for visualization.

# %%
df.describe()
# Out:
#                  G            W        ADJOE        ADJDE      BARTHAG  \
# count  3885.000000  3885.000000  3885.000000  3885.000000  3885.000000
# mean     30.531532    16.075418   103.339743   103.341519     0.493928
# std       3.809623     6.506570     7.315009     6.490684     0.255374
# min       5.000000     0.000000    76.600000    84.000000     0.005000
# 25%      29.000000    11.000000    98.300000    98.600000     0.281200
# 50%      31.000000    16.000000   103.000000   103.500000     0.474000
# 75%      33.000000    21.000000   108.100000   108.000000     0.716400
# max      40.000000    38.000000   129.100000   124.000000     0.984200
#
#              EFG_O        EFG_D          TOR         TORD          ORB  ...  \
# count  3885.000000  3885.000000  3885.000000  3885.000000  3885.000000  ...
# mean     49.935856    50.125946    18.551223    18.483115    29.267310  ...
# std       3.079803     2.855079     2.145057     2.289045     4.201366  ...
# ...

# %%
df.isnull().sum()
# Out:
# TEAM             0
# CONF             0
# G                0
# W                0
# ADJOE            0
# ADJDE            0
# BARTHAG          0
# EFG_O            0
# EFG_D            0
# TOR              0
# TORD             0
# ORB              0
# DRB              0
# FTR              0
# FTRD             0
# 2P_O             0
# 2P_D             0
# 3P_O             0
# 3P_D             0
# ADJ_T            0
# WAB              0
# POSTSEASON    3137
# SEED          3137
# YEAR             0
# dtype: int64

# %%
plt.figure(figsize=(12,6))
top_teams = df.groupby("TEAM")["W"].sum().sort_values(ascending=False).head(10)
sns.barplot(x=top_teams.index, y=top_teams.values, palette="viridis")
plt.xticks(rotation=45)
plt.title("Top 10 Teams by Wins")
plt.show()
# Out:
# /tmp/ipython-input-105000913.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_teams.index, y=top_teams.values, palette="viridis")

# %% [markdown]
# ### Insights – Bar Plot (Top Teams by Wins)
# - **Gonzaga	,Kansas and Duke** consistently dominate with the **highest total wins**.
# - There is a **clear gap** between top-tier and mid-tier teams.
# - These programs are historically **powerhouses in college basketball**.

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(8,6))

# Boxplot with attractive colors
sns.boxplot(
    x=df["ADJOE"],
    color="#FF6F61",     # Coral, bright and attractive
    fliersize=6,          # slightly bigger outliers
    linewidth=2,          # thicker box edges
    medianprops=dict(color="#2E8B57", linewidth=2)  # SeaGreen median line
)

# Title and labels
plt.title("Distribution of Adjusted Offensive Efficiency (ADJOE)", fontsize=16, fontweight="bold", color="#333333")
plt.xlabel("ADJOE", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insights
# - **Box Plot shows the distribution of Offensive Efficiency (ADJOE)** across all teams.
# - The **median ADJOE is around 105**, meaning most teams score near this efficiency level.
# - The **interquartile range (IQR)** lies between ~100 and ~110, showing the central spread.
# - **Outliers exist** on both ends:
#   - Teams with **very low ADJOE (~80–90)** represent weak offensive performers.
#   - Teams with **very high ADJOE (~120–130)** represent exceptionally strong offensive teams.
# - This suggests that while most teams cluster near average efficiency, a few outliers **stand out significantly in performance**.

# %%
# Get a list of all teams
teams = df['TEAM'].unique()

# Generate a unique, attractive color for each team
palette = sns.color_palette("tab20", len(teams))
team_colors = dict(zip(teams, palette))

plt.figure(figsize=(12,8))

# Plot KDE for each team individually with its unique color
for team in teams:
    team_data = df[df['TEAM'] == team]['W']
    if np.var(team_data) > 0:  # check variance
        sns.kdeplot(
            data=team_data,
            fill=True,
            color=team_colors[team],
            alpha=0.6
        )
    else:
        plt.axvline(x=team_data.iloc[0], color=team_colors[team], linestyle='--', alpha=0.6)

plt.title("Distribution of Wins by Team", fontsize=16)
plt.xlabel("Wins")
plt.ylabel("Density")

# Determine top 10 teams based on total Wins
top_10_teams = df.groupby('TEAM')['W'].sum().sort_values(ascending=False).head(10).index

# Create legend only for top 10 teams
handles = [mpatches.Patch(color=team_colors[team], label=team) for team in top_10_teams]
plt.legend(handles=handles, title="Top 10 Teams", bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insights – KDE Plot (Wins Distribution)
# - Most teams cluster around **10–20 wins per season**.
# - **Few teams exceed 25+ wins**, showing how difficult it is to maintain elite performance.
# - The KDE curve confirms that the **majority of teams are average performers**, with only a small tail of top teams.

# %%
plt.figure(figsize=(12,6))
sns.violinplot(x="CONF", y="W", data=df, palette="Set2")
plt.xticks(rotation=90)
plt.title("Wins by Conference")
plt.show()
# Small title
print("\nTop 10 Winning Teams in ACC, B12, and B10 Conferences\n")

# Top teams by Wins in ACC, B12, B10
top_teams = df[df['CONF'].isin(['ACC','B12','B10'])].sort_values(by='W', ascending=False)
print(top_teams[['TEAM','CONF','W']].head(10))
# Out:
# /tmp/ipython-input-14995820.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="CONF", y="W", data=df, palette="Set2")
# Top 10 Winning Teams in ACC, B12, and B10 Conferences
#
#                 TEAM CONF   W
# 1          Wisconsin  B10  36
# 8           Virginia  ACC  35
# 7               Duke  ACC  35
# 2803          Kansas  B12  34
# 2           Michigan  B10  33
# 9     North Carolina  ACC  33
# 0     North Carolina  ACC  33
# 22            Kansas  B12  32
# 44      Michigan St.  B10  32
# 15        Notre Dame  ACC  32

# %% [markdown]
# ### Insights – Violin Plot (Wins by Conference)
# - Conferences like **ACC, B12, and B10** show a **higher concentration of winning teams**.
# - Smaller conferences have **greater variability** and fewer consistently high-win teams.
# - The spread highlights **competitive imbalance** between large vs. small conferences.

# %%
plt.figure(figsize=(14,6))
sns.set_style("whitegrid")  # clean background

# Strip plot with color for each conference
sns.stripplot(
    x="CONF",
    y="ADJOE",
    data=df,
    size=5,               # slightly bigger points for visibility
    jitter=True,
    alpha=0.7,
    palette="Set2"        # attractive colors
)

# Optional: add boxplot behind stripplot for summary stats
sns.boxplot(
    x="CONF",
    y="ADJOE",
    data=df,
    whis=[0,100],         # show full range
    width=0.3,
    showcaps=False,
    boxprops={'facecolor':'None'},  # transparent boxes
    showfliers=False,
    whiskerprops={'linewidth':0}
)

plt.xticks(rotation=45, fontsize=10)
plt.ylabel("Adjusted Offensive Efficiency (ADJOE)", fontsize=12)
plt.xlabel("Conference", fontsize=12)
plt.title("Offensive Efficiency (ADJOE) by Conference", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-974634827.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(

# %% [markdown]
# ### Insights – Strip Plot (Offensive Efficiency by Conference)
# - **ACC, B12, and B10** conferences cluster toward **higher ADJOE values**, confirming stronger overall offenses.
# - Smaller conferences show **wider spread and inconsistency**.
# - Outliers highlight individual teams that **outperform or underperform** compared to their peers.
